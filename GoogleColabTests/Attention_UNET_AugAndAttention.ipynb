# %% [markdown]
# <a href="https://colab.research.google.com/github/Gabril0/CNN/blob/main/Attention_UNET_AugAndAttention.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Summary of the model studied
# The model studied focus mainly in providing an U-NET with a good and robust data augmentation to avoid pitfalls and enhance the learning capabilities.

# %%
#downloading the dataset
# !wget https://prod-dcd-datasets-cache-zipfiles.s3.eu-west-1.amazonaws.com/9bsc36jyrt-1.zip
# Out:
# --2024-04-08 13:52:47--  https://prod-dcd-datasets-cache-zipfiles.s3.eu-west-1.amazonaws.com/9bsc36jyrt-1.zip
# Resolving prod-dcd-datasets-cache-zipfiles.s3.eu-west-1.amazonaws.com (prod-dcd-datasets-cache-zipfiles.s3.eu-west-1.amazonaws.com)... 3.5.64.254, 3.5.65.14, 3.5.69.50, ...
# Connecting to prod-dcd-datasets-cache-zipfiles.s3.eu-west-1.amazonaws.com (prod-dcd-datasets-cache-zipfiles.s3.eu-west-1.amazonaws.com)|3.5.64.254|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1081025712 (1.0G) [application/zip]
# Saving to: ‘9bsc36jyrt-1.zip’
#
# 9bsc36jyrt-1.zip    100%[===================>]   1.01G  27.3MB/s    in 39s
#
# 2024-04-08 13:53:26 (26.7 MB/s) - ‘9bsc36jyrt-1.zip’ saved [1081025712/1081025712]

# %%
#imports
import os
from IPython.display import clear_output
import numpy as np
import matplotlib.pyplot as plt
import cv2
import random
import tensorflow as tf
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Conv2DTranspose,Cropping2D, Concatenate, Activation, BatchNormalization
from keras import Model
from keras.regularizers import l2

# %%
#unzipping
# !unzip /content/9bsc36jyrt-1.zip
# !rm -r "/content/9bsc36jyrt-1.zip"
clear_output()

# %%
#getting path references
#training used only the roi folders

testing_folder1 = "/content/H&E-stained oral squamous cell carcinoma histological images dataset/testing/tumor/patch/640x640/1009009/01-roi"
testing_folder2 = "/content/H&E-stained oral squamous cell carcinoma histological images dataset/testing/tumor/patch/640x640/1009010x1000902/01-roi"
testing_folder3 = "/content/H&E-stained oral squamous cell carcinoma histological images dataset/testing/tumor/patch/640x640/1009011/01-roi"
testing_folder4 = "/content/H&E-stained oral squamous cell carcinoma histological images dataset/testing/tumor/patch/640x640/1009014/01-roi"
testing_folder5 = "/content/H&E-stained oral squamous cell carcinoma histological images dataset/testing/tumor/patch/640x640/1009016x1000903/01-roi"
testing_folder6 = "/content/H&E-stained oral squamous cell carcinoma histological images dataset/testing/tumor/patch/640x640/1009023/01-roi"

training_folder1 = "/content/H&E-stained oral squamous cell carcinoma histological images dataset/training/tumor/patch/640x640/1009009/01-roi"
training_folder2 = "/content/H&E-stained oral squamous cell carcinoma histological images dataset/training/tumor/patch/640x640/1009010x1000902/01-roi"
training_folder3 = "/content/H&E-stained oral squamous cell carcinoma histological images dataset/training/tumor/patch/640x640/1009011/01-roi"
training_folder4 = "/content/H&E-stained oral squamous cell carcinoma histological images dataset/training/tumor/patch/640x640/1009014/01-roi"
training_folder5 = "/content/H&E-stained oral squamous cell carcinoma histological images dataset/training/tumor/patch/640x640/1009016x1000903/01-roi"
training_folder6 = "/content/H&E-stained oral squamous cell carcinoma histological images dataset/training/tumor/patch/640x640/1009023/01-roi"

training_folders = [training_folder1, training_folder2, training_folder3, training_folder4, training_folder5, training_folder6]
#the mask folders will be added dinamically
testing_folders = [testing_folder1, testing_folder2, testing_folder3, testing_folder4, testing_folder5, testing_folder6]

training_path = []
mask_path = []
test_path = []
test_mask_path = []


def append_paths(folder, pathList, complementaryPath):
    full_path = os.path.join(folder, complementaryPath)
    if os.path.isdir(full_path):
        for file in os.listdir(full_path):
            if file.endswith(".png"):
                pathList.append(os.path.join(full_path, file))
            else:
                print("error in file " + file)
    else:
        print("error: " + full_path + " could not be found")

for folder in training_folders: #appending the paths for the original images and respective masks
  append_paths(folder,training_path,"01-original")
  append_paths(folder,mask_path,"02-mask")

for folder in testing_folders: #appending the paths for the test images
  append_paths(folder,test_path,"01-original")
  append_paths(folder,test_mask_path,"02-mask")

# %%
#transforming into numpy array

width = 128
height = 128

def path_to_array(path, numpyArray):
  for file in path:
    image = plt.imread(file)
    image_array = np.array(image)
    resized_image = cv2.resize(image_array, (width,height))
    numpyArray.append(resized_image)

training_array = []
mask_array = []
test_array = []
test_mask_array = []

path_to_array(training_path, training_array)
path_to_array(mask_path, mask_array)
path_to_array(test_path, test_array)
path_to_array(test_mask_path, test_mask_array)

# %%
print(len(training_array))
# Out:
# 361

# %%
#showing an image
plt.imshow(training_array[5])
plt.title('Training Image')
plt.axis('off')

plt.figure(facecolor='black')
plt.imshow(mask_array[5])
plt.title('Training Mask Image',color="white")
plt.axis('off')

plt.tight_layout()
plt.show()

# %%
#data augmentation

from PIL import Image
import random
from scipy import ndimage

def preprocess_mask(mask):
    if mask.dtype == np.float32:
        mask = (mask * 255).astype(np.uint8)

    if mask.shape[-1] != 1:
        mask = np.array(Image.fromarray(mask).convert('L'))

    threshold = 127
    mask = (mask > threshold).astype(np.uint8) * 255

    mask = mask / 255.0

    if len(mask.shape) == 2:
        mask = np.expand_dims(mask, axis=-1)

    return mask

def flip_horizontal(image_array, mask_array):
    aug_images = []
    aug_masks = []
    for image, mask in zip(image_array, mask_array):
        aug_image = np.flip(image, axis=1)
        aug_mask = np.flip(mask, axis=1)

        aug_images.append(aug_image)
        aug_masks.append(aug_mask)

    return aug_images, aug_masks

def flip_vertical(image_array, mask_array):
    aug_images = []
    aug_masks = []
    for image, mask in zip(image_array, mask_array):
        aug_image = np.flip(image, axis=0)
        aug_mask = np.flip(mask, axis=0)

        aug_images.append(aug_image)
        aug_masks.append(aug_mask)

    return aug_images, aug_masks

def random_rotation(image_array, mask_array):
    aug_images = []
    aug_masks = []
    for image, mask in zip(image_array, mask_array):
        random_number = random.randint(0, 359)

        img_rotated = ndimage.rotate(image, random_number, reshape=False)
        mask_rotated = ndimage.rotate(mask, random_number, reshape=False)

        height, width, _ = image.shape
        crop_height = int(height * 0.8)
        crop_width = int(width * 0.8)
        img_cropped = img_rotated[(height - crop_height) // 2: (height + crop_height) // 2,
                                  (width - crop_width) // 2: (width + crop_width) // 2]
        mask_cropped = mask_rotated[(height - crop_height) // 2: (height + crop_height) // 2,
                                    (width - crop_width) // 2: (width + crop_width) // 2]

        img_resized = cv2.resize(img_cropped, (width, height), interpolation=cv2.INTER_AREA)
        mask_resized = cv2.resize(mask_cropped, (width, height), interpolation=cv2.INTER_AREA)

        aug_images.append(img_resized)
        aug_masks.append(mask_resized)

    return aug_images, aug_masks

def optical_distortion(image_array, mask_array, strength=10, zoom=3):
    aug_images = []
    aug_masks = []
    for image, mask in zip(image_array, mask_array):

      center_x, center_y = width // 2, height // 2

      x_coords, y_coords = np.meshgrid(np.arange(width), np.arange(height))
      x_coords = x_coords - center_x
      y_coords = y_coords - center_y

      r = np.sqrt(x_coords**2 + y_coords**2)

      r_distorted = r * (1 + strength * r**2 / (width**2 + height**2)) / (1 + strength * zoom * r**2 / (width**2 + height**2))
      theta_distorted = np.arctan2(y_coords, x_coords)

      x_distorted = r_distorted * np.cos(theta_distorted) + center_x
      y_distorted = r_distorted * np.sin(theta_distorted) + center_y
      distorted_image = cv2.remap(image, x_distorted.astype(np.float32), y_distorted.astype(np.float32), cv2.INTER_LINEAR)
      distorted_mask = cv2.remap(mask, x_distorted.astype(np.float32), y_distorted.astype(np.float32), cv2.INTER_LINEAR)

      aug_images.append(distorted_image)
      aug_masks.append(distorted_mask)

    return aug_images, aug_masks

def grid_distortion(image_array, mask_array, rows=6, cols=6):
    aug_images = []
    aug_masks = []
    for image, mask in zip(image_array, mask_array):
        distort_grid = np.indices(image.shape[:2], dtype=np.float32)
        distort_grid += np.random.normal(size=distort_grid.shape) * 10

        distort_grid[0] = np.clip(distort_grid[0], 0, image.shape[0] - 1)
        distort_grid[1] = np.clip(distort_grid[1], 0, image.shape[1] - 1)

        map_x = distort_grid[1]
        map_y = distort_grid[0]

        distorted_image = cv2.remap(image, map_x, map_y, cv2.INTER_LINEAR)
        distorted_mask = cv2.remap(mask, map_x, map_y, cv2.INTER_LINEAR)

        aug_images.append(distorted_image)
        aug_masks.append(distorted_mask)

    return aug_images, aug_masks

def elastic_transformation(image_array, mask_array):
    aug_images = []
    aug_masks = []
    for image, mask in zip(image_array, mask_array):
        alpha = 50
        sigma = 5

        rows, cols, _ = image.shape

        random_field_x = alpha * cv2.GaussianBlur((np.random.rand(rows, cols) * 2 - 1), (sigma * 2 + 1, sigma * 2 + 1), 0)
        random_field_y = alpha * cv2.GaussianBlur((np.random.rand(rows, cols) * 2 - 1), (sigma * 2 + 1, sigma * 2 + 1), 0)

        grid_x, grid_y = np.meshgrid(np.arange(cols), np.arange(rows))
        grid_x = np.clip(grid_x + random_field_x, 0, cols - 1)
        grid_y = np.clip(grid_y + random_field_y, 0, rows - 1)

        elastic_image = cv2.remap(image, grid_x.astype(np.float32), grid_y.astype(np.float32), interpolation=cv2.INTER_LINEAR)
        elastic_mask = cv2.remap(mask, grid_x.astype(np.float32), grid_y.astype(np.float32), interpolation=cv2.INTER_LINEAR)

        aug_images.append(elastic_image)
        aug_masks.append(elastic_mask)

    return aug_images, aug_masks


augmented_images, augmented_masks = training_array, mask_array

all_augmented_images = [augmented_images]
all_augmented_masks = [augmented_masks]

im, ma = flip_horizontal(training_array, mask_array)
all_augmented_images.append(im)
all_augmented_masks.append(ma)
print("done with horizontal flip, total of images: " + str(len(all_augmented_images[-1])))

im, ma = flip_vertical(training_array, mask_array)
all_augmented_images.append(im)
all_augmented_masks.append(ma)
print("done with vertical flip, total of images: " + str(len(all_augmented_images[-1])))

im, ma = random_rotation(training_array, mask_array)
all_augmented_images.append(im)
all_augmented_masks.append(ma)
print("done with random rotation, total of images: " + str(len(all_augmented_images[-1])))

im, ma = grid_distortion(training_array, mask_array)
all_augmented_images.append(im)
all_augmented_masks.append(ma)
print("done with grid distortion, total of images: " + str(len(all_augmented_images[-1])))

im, ma = optical_distortion(training_array, mask_array)
all_augmented_images.append(im)
all_augmented_masks.append(ma)
print("done with optical distortion, total of images: " + str(len(all_augmented_images[-1])))

im, ma = elastic_transformation(training_array, mask_array)
all_augmented_images.append(im)
all_augmented_masks.append(ma)
print("done with elastic transformation, total of images: " + str(len(all_augmented_images[-1])))

#adding more rotations to training
for i in range(len(all_augmented_images)):
    im, ma = random_rotation(all_augmented_images[i], all_augmented_masks[i])
    all_augmented_images.append(im)
    all_augmented_masks.append(ma)
    print(f"Done with random rotation for image {i+1}, total of images: {len(all_augmented_images[-1])}")

augmented_images = [image for sublist in all_augmented_images for image in sublist]
augmented_masks = [mask for sublist in all_augmented_masks for mask in sublist]

preprocessed_augmented_images = augmented_images
preprocessed_test_array = test_array

preprocessed_test_masks = [preprocess_mask(mask) for mask in test_mask_array]
preprocessed_augmented_masks = [preprocess_mask(mask) for mask in augmented_masks]
# Out:
# done with horizontal flip, total of images: 361
# done with vertical flip, total of images: 361
# done with random rotation, total of images: 361
# done with grid distortion, total of images: 361
# done with optical distortion, total of images: 361
# done with elastic transformation, total of images: 361
# Done with random rotation for image 1, total of images: 361
# Done with random rotation for image 2, total of images: 361
# Done with random rotation for image 3, total of images: 361
# Done with random rotation for image 4, total of images: 361
# Done with random rotation for image 5, total of images: 361
# Done with random rotation for image 6, total of images: 361
# Done with random rotation for image 7, total of images: 361

# %%
# horizontal/vertical flip, rotation, elastictransformation,  grid  distortion  and  optical  distortion.

# %%
index_to_check = 5
original_mask = test_mask_array[index_to_check]
preprocessed_mask = preprocessed_test_masks[index_to_check]

plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.imshow(original_mask)
plt.title('Original Mask')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(preprocessed_mask.squeeze(), cmap='gray')
plt.title('Preprocessed Mask')
plt.axis('off')

plt.show()

plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.hist(original_mask.ravel(), bins=256, color='blue', alpha=0.7)
plt.title('Original Mask Histogram')
plt.xlabel('Pixel Value')
plt.ylabel('Frequency')

plt.subplot(1, 2, 2)
plt.hist(preprocessed_mask.ravel(), bins=256, color='green', alpha=0.7)
plt.title('Preprocessed Mask Histogram')
plt.xlabel('Pixel Value')
plt.ylabel('Frequency')

plt.show()

print(f"Preprocessed mask shape: {preprocessed_mask.shape}")
print(f"Preprocessed mask data type: {preprocessed_mask.dtype}")
print(f"Preprocessed mask min value: {np.min(preprocessed_mask)}")
print(f"Preprocessed mask max value: {np.max(preprocessed_mask)}")
print(f"Preprocessed mask mean value: {np.mean(preprocessed_mask)}")
print(f"Preprocessed mask std deviation: {np.std(preprocessed_mask)}")
# Out:
# Preprocessed mask shape: (128, 128, 1)
# Preprocessed mask data type: float64
# Preprocessed mask min value: 0.0
# Preprocessed mask max value: 1.0
# Preprocessed mask mean value: 0.4356689453125
# Preprocessed mask std deviation: 0.4958442451040386

# %%
print(len(preprocessed_augmented_images))
print(len(preprocessed_augmented_masks))
# Out:
# 5054
# 5054

# %%
#showing data aug results
plt.figure(figsize=(25, 25))
plt.subplots_adjust(wspace=0.2, hspace=0.2)

plt.subplot(4,5, 1)
plt.imshow(preprocessed_augmented_images[3])
plt.title('Regular Training Image')
plt.axis('off')

plt.subplot(4,5, 2)
plt.imshow(preprocessed_augmented_images[364])
plt.title('HFlip Training Image')
plt.axis('off')

plt.subplot(4,5, 3)
plt.imshow(preprocessed_augmented_images[725])
plt.title('VFlip Training Image')
plt.axis('off')

plt.subplot(4,5, 4)
plt.imshow(preprocessed_augmented_images[1086])
plt.title('Random Rotation Training Image')
plt.axis('off')

plt.subplot(4,5, 5)
plt.imshow(preprocessed_augmented_images[1447])
plt.title('GridDistortion Training Image')
plt.axis('off')

plt.subplot(4,5, 6)
plt.imshow(preprocessed_augmented_images[1808])
plt.title('Random Optical Distortion')
plt.axis('off')

plt.subplot(4,5, 7)
plt.imshow(preprocessed_augmented_images[2169])
plt.title('Random Elastic Transformation')
plt.axis('off')

plt.subplot(4,5, 8)
plt.imshow(preprocessed_augmented_masks[1808],cmap='gray')
plt.title('Random Optical Distortion Mask')
plt.axis('off')

plt.subplot(4,5, 9)
plt.imshow(preprocessed_augmented_masks[3],cmap='gray')
plt.title('Original Mask')
plt.axis('off')

plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
#splitting the dataset in 70/30
import random

random.seed(42)

image_mask_pairs = list(zip(augmented_images, augmented_masks))

random.shuffle(image_mask_pairs)

shuffled_images, shuffled_masks = zip(*image_mask_pairs)

split_index = int(0.7 * len(shuffled_images))

train_images = shuffled_images[:split_index]
test_images = shuffled_images[split_index:]
train_masks = shuffled_masks[:split_index]
test_masks = shuffled_masks[split_index:]

preprocessed_train_masks = [preprocess_mask(mask) for mask in train_masks]
preprocessed_test_masks = [preprocess_mask(mask) for mask in test_masks]

preprocessed_test_array = test_images[:len(test_masks)]


preprocessed_augmented_masks = preprocessed_train_masks
preprocessed_augmented_images = train_images

# %%
#constructing the UNET functions

def conv_block(inputs,filters):
  #two conv layers with batch normalization and relu, this makes features more apparent as the tiny weight get smaller and big ones grow
  conv = Conv2D(filters, kernel_size=(3, 3), strides=(1, 1), padding='same')(inputs)
  conv = BatchNormalization()(conv)
  conv = Activation('relu')(conv)
  conv = Conv2D(filters, kernel_size=(3, 3), strides=(1, 1), padding='same')(conv)
  conv = BatchNormalization()(conv)
  conv = Activation('relu')(conv)
  return conv

def attention_gate(input_tensor, skip_tensor, filters):
  #relu
  attn = Conv2D(filters, kernel_size=(1, 1), strides=(1, 1), padding='same')(input_tensor)
  attn = BatchNormalization()(attn)
  attn = Activation('relu')(attn)

  #sigmoid
  attn = Conv2D(filters, kernel_size=(1, 1), strides=(2, 2), padding='same')(attn)
  attn = BatchNormalization()(attn)
  attn = Activation('sigmoid')(attn)

  #resampler
  attn = UpSampling2D(size=(2, 2))(attn)
  attn = Conv2D(filters, kernel_size=(3, 3), strides=(1, 1), padding='same')(attn)

  #multiplication with the skip_tensor layer
  multiplied = tf.multiply(skip_tensor, attn)

  concatenated = Concatenate()([input_tensor, multiplied])
  return concatenated

def unet_build(input_shape):
  inputs = Input(input_shape)

  #downsampling
  conv1 = conv_block(inputs, 64)
  pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

  conv2 = conv_block(pool1, 128)
  pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

  conv3 = conv_block(pool2, 256)
  pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

  conv4 = conv_block(pool3, 512)
  pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

  #bridge
  conv5 = conv_block(pool4, 1024)

  #upsampling
  up6 = UpSampling2D(size=(2, 2))(conv5)
  up6 = attention_gate(up6, conv4, 512)
  conv6 = conv_block(up6, 512)

  up7 = UpSampling2D(size=(2, 2))(conv6)
  up7 = attention_gate(up7, conv3, 256)
  conv7 = conv_block(up7, 256)

  up8 = UpSampling2D(size=(2, 2))(conv7)
  up8 = attention_gate(up8, conv2, 128)
  conv8 = conv_block(up8, 128)

  up9 = UpSampling2D(size=(2, 2))(conv8)
  up9 = attention_gate(up9, conv1, 64)
  conv9 = conv_block(up9, 64)

  outputs = Conv2D(1, kernel_size=(1, 1), strides=(1, 1), activation='sigmoid')(conv9)

  model = Model(inputs=inputs, outputs=outputs)
  return model

# %%
#creation of the network
input_shape = (width, height, 3)
model = unet_build(input_shape)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 128, 128, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 128, 128, 64)         1792      ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 128, 128, 64)         256       ['conv2d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 128, 128, 64)         0         ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 128, 128, 64)         36928     ['activation[0][0]']
#
#  batch_normalization_1 (Bat  (None, 128, 128, 64)         256       ['conv2d_1[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 128, 128, 64)         0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  max_pooling2d (MaxPooling2  (None, 64, 64, 64)           0         ['activation_1[0][0]']
#  D)
#
#  conv2d_2 (Conv2D)           (None, 64, 64, 128)          73856     ['max_pooling2d[0][0]']
#
#  batch_normalization_2 (Bat  (None, 64, 64, 128)          512       ['conv2d_2[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 64, 64, 128)          0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  conv2d_3 (Conv2D)           (None, 64, 64, 128)          147584    ['activation_2[0][0]']
#
#  batch_normalization_3 (Bat  (None, 64, 64, 128)          512       ['conv2d_3[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 64, 64, 128)          0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  max_pooling2d_1 (MaxPoolin  (None, 32, 32, 128)          0         ['activation_3[0][0]']
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 32, 32, 256)          295168    ['max_pooling2d_1[0][0]']
#
#  batch_normalization_4 (Bat  (None, 32, 32, 256)          1024      ['conv2d_4[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 32, 32, 256)          0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  conv2d_5 (Conv2D)           (None, 32, 32, 256)          590080    ['activation_4[0][0]']
#
#  batch_normalization_5 (Bat  (None, 32, 32, 256)          1024      ['conv2d_5[0][0]']
#  chNormalization)
#
#  activation_5 (Activation)   (None, 32, 32, 256)          0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  max_pooling2d_2 (MaxPoolin  (None, 16, 16, 256)          0         ['activation_5[0][0]']
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 16, 16, 512)          1180160   ['max_pooling2d_2[0][0]']
#
#  batch_normalization_6 (Bat  (None, 16, 16, 512)          2048      ['conv2d_6[0][0]']
#  chNormalization)
#
#  activation_6 (Activation)   (None, 16, 16, 512)          0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  conv2d_7 (Conv2D)           (None, 16, 16, 512)          2359808   ['activation_6[0][0]']
#
#  batch_normalization_7 (Bat  (None, 16, 16, 512)          2048      ['conv2d_7[0][0]']
#  chNormalization)
#
#  activation_7 (Activation)   (None, 16, 16, 512)          0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  max_pooling2d_3 (MaxPoolin  (None, 8, 8, 512)            0         ['activation_7[0][0]']
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 8, 8, 1024)           4719616   ['max_pooling2d_3[0][0]']
#
#  batch_normalization_8 (Bat  (None, 8, 8, 1024)           4096      ['conv2d_8[0][0]']
#  chNormalization)
#
#  activation_8 (Activation)   (None, 8, 8, 1024)           0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  conv2d_9 (Conv2D)           (None, 8, 8, 1024)           9438208   ['activation_8[0][0]']
#
#  batch_normalization_9 (Bat  (None, 8, 8, 1024)           4096      ['conv2d_9[0][0]']
#  chNormalization)
#
#  activation_9 (Activation)   (None, 8, 8, 1024)           0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  up_sampling2d (UpSampling2  (None, 16, 16, 1024)         0         ['activation_9[0][0]']
#  D)
#
#  conv2d_10 (Conv2D)          (None, 16, 16, 512)          524800    ['up_sampling2d[0][0]']
#
#  batch_normalization_10 (Ba  (None, 16, 16, 512)          2048      ['conv2d_10[0][0]']
#  tchNormalization)
#
#  activation_10 (Activation)  (None, 16, 16, 512)          0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  conv2d_11 (Conv2D)          (None, 8, 8, 512)            262656    ['activation_10[0][0]']
#
#  batch_normalization_11 (Ba  (None, 8, 8, 512)            2048      ['conv2d_11[0][0]']
#  tchNormalization)
#
#  activation_11 (Activation)  (None, 8, 8, 512)            0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  up_sampling2d_1 (UpSamplin  (None, 16, 16, 512)          0         ['activation_11[0][0]']
#  g2D)
#
#  conv2d_12 (Conv2D)          (None, 16, 16, 512)          2359808   ['up_sampling2d_1[0][0]']
#
#  tf.math.multiply (TFOpLamb  (None, 16, 16, 512)          0         ['activation_7[0][0]',
#  da)                                                                 'conv2d_12[0][0]']
#
#  concatenate (Concatenate)   (None, 16, 16, 1536)         0         ['up_sampling2d[0][0]',
#                                                                      'tf.math.multiply[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 16, 16, 512)          7078400   ['concatenate[0][0]']
#
#  batch_normalization_12 (Ba  (None, 16, 16, 512)          2048      ['conv2d_13[0][0]']
#  tchNormalization)
#
#  activation_12 (Activation)  (None, 16, 16, 512)          0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  conv2d_14 (Conv2D)          (None, 16, 16, 512)          2359808   ['activation_12[0][0]']
#
#  batch_normalization_13 (Ba  (None, 16, 16, 512)          2048      ['conv2d_14[0][0]']
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 16, 16, 512)          0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  up_sampling2d_2 (UpSamplin  (None, 32, 32, 512)          0         ['activation_13[0][0]']
#  g2D)
#
#  conv2d_15 (Conv2D)          (None, 32, 32, 256)          131328    ['up_sampling2d_2[0][0]']
#
#  batch_normalization_14 (Ba  (None, 32, 32, 256)          1024      ['conv2d_15[0][0]']
#  tchNormalization)
#
#  activation_14 (Activation)  (None, 32, 32, 256)          0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  conv2d_16 (Conv2D)          (None, 16, 16, 256)          65792     ['activation_14[0][0]']
#
#  batch_normalization_15 (Ba  (None, 16, 16, 256)          1024      ['conv2d_16[0][0]']
#  tchNormalization)
#
#  activation_15 (Activation)  (None, 16, 16, 256)          0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  up_sampling2d_3 (UpSamplin  (None, 32, 32, 256)          0         ['activation_15[0][0]']
#  g2D)
#
#  conv2d_17 (Conv2D)          (None, 32, 32, 256)          590080    ['up_sampling2d_3[0][0]']
#
#  tf.math.multiply_1 (TFOpLa  (None, 32, 32, 256)          0         ['activation_5[0][0]',
#  mbda)                                                               'conv2d_17[0][0]']
#
#  concatenate_1 (Concatenate  (None, 32, 32, 768)          0         ['up_sampling2d_2[0][0]',
#  )                                                                   'tf.math.multiply_1[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 32, 32, 256)          1769728   ['concatenate_1[0][0]']
#
#  batch_normalization_16 (Ba  (None, 32, 32, 256)          1024      ['conv2d_18[0][0]']
#  tchNormalization)
#
#  activation_16 (Activation)  (None, 32, 32, 256)          0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  conv2d_19 (Conv2D)          (None, 32, 32, 256)          590080    ['activation_16[0][0]']
#
#  batch_normalization_17 (Ba  (None, 32, 32, 256)          1024      ['conv2d_19[0][0]']
#  tchNormalization)
#
#  activation_17 (Activation)  (None, 32, 32, 256)          0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  up_sampling2d_4 (UpSamplin  (None, 64, 64, 256)          0         ['activation_17[0][0]']
#  g2D)
#
#  conv2d_20 (Conv2D)          (None, 64, 64, 128)          32896     ['up_sampling2d_4[0][0]']
#
#  batch_normalization_18 (Ba  (None, 64, 64, 128)          512       ['conv2d_20[0][0]']
#  tchNormalization)
#
#  activation_18 (Activation)  (None, 64, 64, 128)          0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  conv2d_21 (Conv2D)          (None, 32, 32, 128)          16512     ['activation_18[0][0]']
#
#  batch_normalization_19 (Ba  (None, 32, 32, 128)          512       ['conv2d_21[0][0]']
#  tchNormalization)
#
#  activation_19 (Activation)  (None, 32, 32, 128)          0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  up_sampling2d_5 (UpSamplin  (None, 64, 64, 128)          0         ['activation_19[0][0]']
#  g2D)
#
#  conv2d_22 (Conv2D)          (None, 64, 64, 128)          147584    ['up_sampling2d_5[0][0]']
#
#  tf.math.multiply_2 (TFOpLa  (None, 64, 64, 128)          0         ['activation_3[0][0]',
#  mbda)                                                               'conv2d_22[0][0]']
#
#  concatenate_2 (Concatenate  (None, 64, 64, 384)          0         ['up_sampling2d_4[0][0]',
#  )                                                                   'tf.math.multiply_2[0][0]']
#
#  conv2d_23 (Conv2D)          (None, 64, 64, 128)          442496    ['concatenate_2[0][0]']
#
#  batch_normalization_20 (Ba  (None, 64, 64, 128)          512       ['conv2d_23[0][0]']
#  tchNormalization)
#
#  activation_20 (Activation)  (None, 64, 64, 128)          0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  conv2d_24 (Conv2D)          (None, 64, 64, 128)          147584    ['activation_20[0][0]']
#
#  batch_normalization_21 (Ba  (None, 64, 64, 128)          512       ['conv2d_24[0][0]']
#  tchNormalization)
#
#  activation_21 (Activation)  (None, 64, 64, 128)          0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  up_sampling2d_6 (UpSamplin  (None, 128, 128, 128)        0         ['activation_21[0][0]']
#  g2D)
#
#  conv2d_25 (Conv2D)          (None, 128, 128, 64)         8256      ['up_sampling2d_6[0][0]']
#
#  batch_normalization_22 (Ba  (None, 128, 128, 64)         256       ['conv2d_25[0][0]']
#  tchNormalization)
#
#  activation_22 (Activation)  (None, 128, 128, 64)         0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  conv2d_26 (Conv2D)          (None, 64, 64, 64)           4160      ['activation_22[0][0]']
#
#  batch_normalization_23 (Ba  (None, 64, 64, 64)           256       ['conv2d_26[0][0]']
#  tchNormalization)
#
#  activation_23 (Activation)  (None, 64, 64, 64)           0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  up_sampling2d_7 (UpSamplin  (None, 128, 128, 64)         0         ['activation_23[0][0]']
#  g2D)
#
#  conv2d_27 (Conv2D)          (None, 128, 128, 64)         36928     ['up_sampling2d_7[0][0]']
#
#  tf.math.multiply_3 (TFOpLa  (None, 128, 128, 64)         0         ['activation_1[0][0]',
#  mbda)                                                               'conv2d_27[0][0]']
#
#  concatenate_3 (Concatenate  (None, 128, 128, 192)        0         ['up_sampling2d_6[0][0]',
#  )                                                                   'tf.math.multiply_3[0][0]']
#
#  conv2d_28 (Conv2D)          (None, 128, 128, 64)         110656    ['concatenate_3[0][0]']
#
#  batch_normalization_24 (Ba  (None, 128, 128, 64)         256       ['conv2d_28[0][0]']
#  tchNormalization)
#
#  activation_24 (Activation)  (None, 128, 128, 64)         0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  conv2d_29 (Conv2D)          (None, 128, 128, 64)         36928     ['activation_24[0][0]']
#
#  batch_normalization_25 (Ba  (None, 128, 128, 64)         256       ['conv2d_29[0][0]']
#  tchNormalization)
#
#  activation_25 (Activation)  (None, 128, 128, 64)         0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  conv2d_30 (Conv2D)          (None, 128, 128, 1)          65        ['activation_25[0][0]']
#
# ==================================================================================================
# Total params: 35590977 (135.77 MB)
# Trainable params: 35575361 (135.71 MB)
# Non-trainable params: 15616 (61.00 KB)
# __________________________________________________________________________________________________

# %%
preprocessed_augmented_images = np.array(preprocessed_augmented_images)
preprocessed_augmented_masks = np.array(preprocessed_augmented_masks)
preprocessed_test_array = np.array(preprocessed_test_array)
preprocessed_test_masks= np.array(preprocessed_test_masks)

# %%
print("Shape of augmented_images:", preprocessed_augmented_images.shape)
print("Shape of augmented_masks:", preprocessed_augmented_masks.shape)
print("Shape of test_array:", preprocessed_test_array.shape)
print("Shape of test_mask_array:", preprocessed_test_masks.shape)
# Out:
# Shape of augmented_images: (3537, 128, 128, 3)
# Shape of augmented_masks: (3537, 128, 128, 1)
# Shape of test_array: (1517, 128, 128, 3)
# Shape of test_mask_array: (1517, 128, 128, 1)

# %%
#augmented_images_with_channel = np.concatenate([augmented_images, np.ones_like(augmented_images[..., :1])], axis=-1)
#test_array_with_channel = np.concatenate([test_array, np.ones_like(test_array[..., :1])], axis=-1)

#print("Shape of augmented_images after adding channel:", augmented_images_with_channel.shape)
#print("Shape of test_array after adding channel:", test_array_with_channel.shape)

# %%
plt.subplot(3, 2, 1)
plt.imshow(preprocessed_test_array[10])
plt.axis('off')

plt.subplot(3, 2, 2)
plt.imshow(preprocessed_test_masks[10])
plt.axis('off')

plt.show()

# %%
#training
model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])


#test_images = np.squeeze(test_images)
#test_masks = np.squeeze(test_masks)
#print("Updated Test images shape:", test_images.shape)
#print("Updated Test masks shape:", test_masks.shape)



history = model.fit(preprocessed_augmented_images,
                    preprocessed_augmented_masks,
                    validation_data=(preprocessed_test_array, preprocessed_test_masks),
                    epochs=50,
                    batch_size=8)
# Out:
# Epoch 1/50
# 443/443 [==============================] - 150s 262ms/step - loss: 0.5202 - accuracy: 0.7426 - val_loss: 1.1761 - val_accuracy: 0.6143
# Epoch 2/50
# 443/443 [==============================] - 105s 236ms/step - loss: 0.4854 - accuracy: 0.7710 - val_loss: 0.8493 - val_accuracy: 0.6163
# Epoch 3/50
# 443/443 [==============================] - 113s 256ms/step - loss: 0.4658 - accuracy: 0.7825 - val_loss: 0.9272 - val_accuracy: 0.6185
# Epoch 4/50
# 443/443 [==============================] - 105s 237ms/step - loss: 0.4465 - accuracy: 0.7944 - val_loss: 0.5804 - val_accuracy: 0.7022
# Epoch 5/50
# 443/443 [==============================] - 113s 256ms/step - loss: 0.4335 - accuracy: 0.8031 - val_loss: 1.2270 - val_accuracy: 0.5781
# Epoch 6/50
# 443/443 [==============================] - 113s 256ms/step - loss: 0.4235 - accuracy: 0.8090 - val_loss: 1.0072 - val_accuracy: 0.6299
# Epoch 7/50
# 443/443 [==============================] - 114s 256ms/step - loss: 0.4116 - accuracy: 0.8156 - val_loss: 0.7876 - val_accuracy: 0.6200
# Epoch 8/50
# 443/443 [==============================] - 114s 256ms/step - loss: 0.4020 - accuracy: 0.8216 - val_loss: 0.7412 - val_accuracy: 0.7017
# Epoch 9/50
# 443/443 [==============================] - 114s 256ms/step - loss: 0.3993 - accuracy: 0.8229 - val_loss: 0.4781 - val_accuracy: 0.7886
# Epoch 10/50
# 443/443 [==============================] - 114s 256ms/step - loss: 0.3909 - accuracy: 0.8273 - val_loss: 0.7450 - val_accuracy: 0.6876
# Epoch 11/50
# 443/443 [==============================] - 114s 256ms/step - loss: 0.3793 - accuracy: 0.8340 - val_loss: 0.6604 - val_accuracy: 0.6526
# Epoch 12/50
# 443/443 [==============================] - 106s 238ms/step - loss: 0.3671 - accuracy: 0.8398 - val_loss: 1.1295 - val_accuracy: 0.6242
# Epoch 13/50
# 443/443 [==============================] - 113s 256ms/step - loss: 0.3618 - accuracy: 0.8426 - val_loss: 0.7943 - val_accuracy: 0.6235
# Epoch 14/50
# 443/443 [==============================] - 114s 257ms/step - loss: 0.3578 - accuracy: 0.8459 - val_loss: 1.5618 - val_accuracy: 0.6384
# Epoch 15/50
# 443/443 [==============================] - 114s 257ms/step - loss: 0.3494 - accuracy: 0.8495 - val_loss: 1.3224 - val_accuracy: 0.6175
# Epoch 16/50
# 443/443 [==============================] - 114s 257ms/step - loss: 0.3451 - accuracy: 0.8506 - val_loss: 0.5130 - val_accuracy: 0.7603
# Epoch 17/50
# 443/443 [==============================] - 114s 257ms/step - loss: 0.3346 - accuracy: 0.8556 - val_loss: 1.4536 - val_accuracy: 0.6332
# Epoch 18/50
# 443/443 [==============================] - 114s 257ms/step - loss: 0.3305 - accuracy: 0.8561 - val_loss: 0.4728 - val_accuracy: 0.7768
# Epoch 19/50
# 443/443 [==============================] - 114s 257ms/step - loss: 0.3228 - accuracy: 0.8600 - val_loss: 2.0392 - val_accuracy: 0.6123
# Epoch 20/50
# 443/443 [==============================] - 114s 257ms/step - loss: 0.3165 - accuracy: 0.8631 - val_loss: 0.7631 - val_accuracy: 0.6709
# Epoch 21/50
# 443/443 [==============================] - 113s 256ms/step - loss: 0.3134 - accuracy: 0.8642 - val_loss: 0.4689 - val_accuracy: 0.7572
# Epoch 22/50
# 443/443 [==============================] - 105s 238ms/step - loss: 0.3098 - accuracy: 0.8671 - val_loss: 1.1238 - val_accuracy: 0.6797
# Epoch 23/50
# 443/443 [==============================] - 105s 238ms/step - loss: 0.3052 - accuracy: 0.8679 - val_loss: 1.0509 - val_accuracy: 0.6279
# Epoch 24/50
# 443/443 [==============================] - 105s 238ms/step - loss: 0.2962 - accuracy: 0.8717 - val_loss: 2.5342 - val_accuracy: 0.6116
# Epoch 25/50
# 443/443 [==============================] - 114s 257ms/step - loss: 0.3018 - accuracy: 0.8700 - val_loss: 0.5588 - val_accuracy: 0.7727
# Epoch 26/50
# 443/443 [==============================] - 114s 257ms/step - loss: 0.2975 - accuracy: 0.8721 - val_loss: 1.2522 - val_accuracy: 0.5596
# Epoch 27/50
# 443/443 [==============================] - 105s 238ms/step - loss: 0.2998 - accuracy: 0.8704 - val_loss: 1.0216 - val_accuracy: 0.6989
# Epoch 28/50
# 443/443 [==============================] - 114s 256ms/step - loss: 0.2853 - accuracy: 0.8773 - val_loss: 0.5324 - val_accuracy: 0.7623
# Epoch 29/50
# 443/443 [==============================] - 113s 256ms/step - loss: 0.2805 - accuracy: 0.8789 - val_loss: 1.4360 - val_accuracy: 0.6604
# Epoch 30/50
# 443/443 [==============================] - 114s 256ms/step - loss: 0.2796 - accuracy: 0.8797 - val_loss: 2.4913 - val_accuracy: 0.6153
# Epoch 31/50
# 443/443 [==============================] - 114s 257ms/step - loss: 0.2737 - accuracy: 0.8831 - val_loss: 0.7195 - val_accuracy: 0.6933
# Epoch 32/50
# 443/443 [==============================] - 114s 256ms/step - loss: 0.2804 - accuracy: 0.8796 - val_loss: 0.6235 - val_accuracy: 0.7190
# Epoch 33/50
# 443/443 [==============================] - 114s 256ms/step - loss: 0.2704 - accuracy: 0.8837 - val_loss: 0.3158 - val_accuracy: 0.8581
# Epoch 34/50
# 443/443 [==============================] - 114s 256ms/step - loss: 0.2727 - accuracy: 0.8820 - val_loss: 0.6292 - val_accuracy: 0.7539
# Epoch 35/50
# 443/443 [==============================] - 105s 237ms/step - loss: 0.2659 - accuracy: 0.8853 - val_loss: 0.3880 - val_accuracy: 0.8192
# Epoch 36/50
# 443/443 [==============================] - 105s 237ms/step - loss: 0.2604 - accuracy: 0.8880 - val_loss: 0.4907 - val_accuracy: 0.7871
# Epoch 37/50
# 443/443 [==============================] - 113s 256ms/step - loss: 0.2587 - accuracy: 0.8886 - val_loss: 0.7577 - val_accuracy: 0.7645
# Epoch 38/50
# 443/443 [==============================] - 113s 256ms/step - loss: 0.2643 - accuracy: 0.8863 - val_loss: 0.4751 - val_accuracy: 0.7663
# Epoch 39/50
# 443/443 [==============================] - 113s 256ms/step - loss: 0.2555 - accuracy: 0.8902 - val_loss: 0.5731 - val_accuracy: 0.7331
# Epoch 40/50
# 443/443 [==============================] - 113s 256ms/step - loss: 0.2549 - accuracy: 0.8904 - val_loss: 0.8712 - val_accuracy: 0.7605
# Epoch 41/50
# 443/443 [==============================] - 113s 256ms/step - loss: 0.2571 - accuracy: 0.8883 - val_loss: 2.6302 - val_accuracy: 0.6105
# Epoch 42/50
# 443/443 [==============================] - 113s 256ms/step - loss: 0.2471 - accuracy: 0.8931 - val_loss: 0.3188 - val_accuracy: 0.8607
# Epoch 43/50
# 443/443 [==============================] - 105s 237ms/step - loss: 0.2416 - accuracy: 0.8957 - val_loss: 0.6929 - val_accuracy: 0.7466
# Epoch 44/50
# 443/443 [==============================] - 113s 256ms/step - loss: 0.2469 - accuracy: 0.8939 - val_loss: 0.5231 - val_accuracy: 0.7757
# Epoch 45/50
# 443/443 [==============================] - 113s 256ms/step - loss: 0.2474 - accuracy: 0.8922 - val_loss: 2.1899 - val_accuracy: 0.6339
# Epoch 46/50
# 443/443 [==============================] - 114s 256ms/step - loss: 0.2409 - accuracy: 0.8960 - val_loss: 0.9318 - val_accuracy: 0.7498
# Epoch 47/50
# 443/443 [==============================] - 113s 256ms/step - loss: 0.2363 - accuracy: 0.8976 - val_loss: 1.1167 - val_accuracy: 0.6303
# Epoch 48/50
# 443/443 [==============================] - 105s 237ms/step - loss: 0.2367 - accuracy: 0.8975 - val_loss: 0.4683 - val_accuracy: 0.8151
# Epoch 49/50
# 443/443 [==============================] - 113s 255ms/step - loss: 0.2353 - accuracy: 0.8976 - val_loss: 0.5653 - val_accuracy: 0.8129
# Epoch 50/50
# 443/443 [==============================] - 105s 237ms/step - loss: 0.2280 - accuracy: 0.9007 - val_loss: 1.0431 - val_accuracy: 0.6880

# %%
#evaluate the model
loss, accuracy = model.evaluate(preprocessed_test_array, preprocessed_test_masks)
print("Test Loss:", loss)
print("Test Accuracy:", accuracy)
# Out:
# 48/48 [==============================] - 25s 324ms/step - loss: 1.0431 - accuracy: 0.6880
# Test Loss: 1.0430867671966553
# Test Accuracy: 0.6879658102989197

# %%
#testing

image_index = 54

test_image = preprocessed_test_array[image_index]
test_mask = preprocessed_test_masks[image_index]

test_image = np.expand_dims(test_image, axis=0)

predicted_mask = model.predict(test_image)

threshold_value = 0.2
thresholded_mask = (predicted_mask > threshold_value).astype(np.uint8)

plt.figure(figsize=(12, 6))

plt.subplot(1, 3, 1)
plt.imshow(test_image.squeeze(), cmap='gray')
plt.axis('off')
plt.title('Original Image')

plt.subplot(1, 3, 2)
plt.imshow(test_mask.squeeze(), cmap='gray')
plt.axis('off')
plt.title('Ground Truth Mask')

plt.subplot(1, 3, 3)
plt.imshow(thresholded_mask.squeeze(), cmap='gray')
plt.axis('off')
plt.title('Thresholded Predicted Mask')

plt.show()
# Out:
# 1/1 [==============================] - 1s 914ms/step

# %%
fig, axs = plt.subplots(1, 2, figsize=(15, 5))

axs[0].imshow(test_image.squeeze())
axs[0].imshow(thresholded_mask.squeeze(), alpha=0.5)
axs[0].axis('off')
axs[0].set_title('Overlay with the predicted mask')

axs[1].imshow(test_image.squeeze())
axs[1].imshow(test_mask.squeeze(), alpha=0.5)
axs[1].axis('off')
axs[1].set_title('Overlay with the original mask')

plt.tight_layout()

plt.show()

# %%
#analytics

plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

plt.figure(figsize=(12, 6))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
