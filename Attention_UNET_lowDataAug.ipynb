# %% [markdown]
# <a href="https://colab.research.google.com/github/Gabril0/CNN/blob/main/Attention_UNET_lowDataAug.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Summary of the model studied
# The model studied focus mainly in providing an U-NET with a good and robust data augmentation to avoid pitfalls and enhance the learning capabilities.

# %%
#downloading the dataset
# !wget https://prod-dcd-datasets-cache-zipfiles.s3.eu-west-1.amazonaws.com/9bsc36jyrt-1.zip
# Out:
# --2024-03-28 19:57:38--  https://prod-dcd-datasets-cache-zipfiles.s3.eu-west-1.amazonaws.com/9bsc36jyrt-1.zip
# Resolving prod-dcd-datasets-cache-zipfiles.s3.eu-west-1.amazonaws.com (prod-dcd-datasets-cache-zipfiles.s3.eu-west-1.amazonaws.com)... 52.218.61.112, 52.218.122.114, 52.218.97.139, ...
# Connecting to prod-dcd-datasets-cache-zipfiles.s3.eu-west-1.amazonaws.com (prod-dcd-datasets-cache-zipfiles.s3.eu-west-1.amazonaws.com)|52.218.61.112|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1081025712 (1.0G) [application/zip]
# Saving to: ‘9bsc36jyrt-1.zip’
#
# 9bsc36jyrt-1.zip    100%[===================>]   1.01G  28.7MB/s    in 36s
#
# 2024-03-28 19:58:15 (28.9 MB/s) - ‘9bsc36jyrt-1.zip’ saved [1081025712/1081025712]

# %%
#imports
import os
from IPython.display import clear_output
import numpy as np
import matplotlib.pyplot as plt
import cv2
import random
import tensorflow as tf
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Conv2DTranspose,Cropping2D, Concatenate, Activation, BatchNormalization
from keras import Model
from keras.regularizers import l2

# %%
#unzipping
# !unzip /content/9bsc36jyrt-1.zip
# !rm -r "/content/9bsc36jyrt-1.zip"
clear_output()

# %%
#getting path references
#training used only the roi folders

testing_folder1 = "/content/H&E-stained oral squamous cell carcinoma histological images dataset/testing/tumor/patch/640x640/1009009/01-roi"
testing_folder2 = "/content/H&E-stained oral squamous cell carcinoma histological images dataset/testing/tumor/patch/640x640/1009010x1000902/01-roi"
testing_folder3 = "/content/H&E-stained oral squamous cell carcinoma histological images dataset/testing/tumor/patch/640x640/1009011/01-roi"
testing_folder4 = "/content/H&E-stained oral squamous cell carcinoma histological images dataset/testing/tumor/patch/640x640/1009014/01-roi"
testing_folder5 = "/content/H&E-stained oral squamous cell carcinoma histological images dataset/testing/tumor/patch/640x640/1009016x1000903/01-roi"
testing_folder6 = "/content/H&E-stained oral squamous cell carcinoma histological images dataset/testing/tumor/patch/640x640/1009023/01-roi"

training_folder1 = "/content/H&E-stained oral squamous cell carcinoma histological images dataset/training/tumor/patch/640x640/1009009/01-roi"
training_folder2 = "/content/H&E-stained oral squamous cell carcinoma histological images dataset/training/tumor/patch/640x640/1009010x1000902/01-roi"
training_folder3 = "/content/H&E-stained oral squamous cell carcinoma histological images dataset/training/tumor/patch/640x640/1009011/01-roi"
training_folder4 = "/content/H&E-stained oral squamous cell carcinoma histological images dataset/training/tumor/patch/640x640/1009014/01-roi"
training_folder5 = "/content/H&E-stained oral squamous cell carcinoma histological images dataset/training/tumor/patch/640x640/1009016x1000903/01-roi"
training_folder6 = "/content/H&E-stained oral squamous cell carcinoma histological images dataset/training/tumor/patch/640x640/1009023/01-roi"

training_folders = [training_folder1, training_folder2, training_folder3, training_folder4, training_folder5, training_folder6]
#the mask folders will be added dinamically
testing_folders = [testing_folder1, testing_folder2, testing_folder3, testing_folder4, testing_folder5, testing_folder6]

training_path = []
mask_path = []
test_path = []
test_mask_path = []


def append_paths(folder, pathList, complementaryPath):
    full_path = os.path.join(folder, complementaryPath)
    if os.path.isdir(full_path):
        for file in os.listdir(full_path):
            if file.endswith(".png"):
                pathList.append(os.path.join(full_path, file))
            else:
                print("error in file " + file)
    else:
        print("error: " + full_path + " could not be found")

for folder in training_folders: #appending the paths for the original images and respective masks
  append_paths(folder,training_path,"01-original")
  append_paths(folder,mask_path,"02-mask")

for folder in testing_folders: #appending the paths for the test images
  append_paths(folder,test_path,"01-original")
  append_paths(folder,test_mask_path,"02-mask")

# %%
#transforming into numpy array

width = 192
height = 192

def path_to_array(path, numpyArray):
  for file in path:
    image = plt.imread(file)
    image_array = np.array(image)
    resized_image = cv2.resize(image_array, (width,height))
    numpyArray.append(resized_image)

training_array = []
mask_array = []
test_array = []
test_mask_array = []

path_to_array(training_path, training_array)
path_to_array(mask_path, mask_array)
path_to_array(test_path, test_array)
path_to_array(test_mask_path, test_mask_array)

# %%
print(len(training_array))
# Out:
# 361

# %%
#showing an image
plt.imshow(training_array[5])
plt.title('Training Image')
plt.axis('off')

plt.figure(facecolor='black')
plt.imshow(mask_array[5])
plt.title('Training Mask Image',color="white")
plt.axis('off')

plt.tight_layout()
plt.show()

# %%
#data augmentation
#do data augmentation horizontal flip, vertical flip, rotation, transpose, grid distortion,
#optical distortion, color transfer, inpainting
#def preprocess_mask(mask):
#    mask_gray = cv2.cvtColor(mask, cv2.COLOR_BGR2GRAY)
#    mask_normalized = mask_gray / 255.0
#    mask_expanded = np.expand_dims(mask_normalized, axis=-1)
#    return mask_expanded
from PIL import Image

def preprocess_mask(mask):
    if mask.dtype == np.float32:
        mask = (mask * 255).astype(np.uint8)

    if mask.shape[-1] != 1:
        mask = np.array(Image.fromarray(mask).convert('L'))

    threshold = 127
    mask = (mask > threshold).astype(np.uint8) * 255

    mask = mask / 255.0

    if len(mask.shape) == 2:
        mask = np.expand_dims(mask, axis=-1)

    return mask

def flip_horizontal(image_array, mask_array):
    aug_images = []
    aug_masks = []
    for image, mask in zip(image_array, mask_array):
        aug_image = np.flip(image, axis=1)
        aug_mask = np.flip(mask, axis=1)

        aug_images.append(aug_image)
        aug_masks.append(aug_mask)

    return aug_images, aug_masks

def flip_vertical(image_array, mask_array):
    aug_images = []
    aug_masks = []
    for image, mask in zip(image_array, mask_array):
        aug_image = np.flip(image, axis=0)
        aug_mask = np.flip(mask, axis=0)

        aug_images.append(aug_image)
        aug_masks.append(aug_mask)

    return aug_images, aug_masks

def random_rotation(image_array, mask_array):
    aug_images = []
    aug_masks = []
    for image, mask in zip(image_array, mask_array):
        angle = random.uniform(0, 360)

        height, width = image.shape[:2]

        rotation_matrix = cv2.getRotationMatrix2D((width / 2, height / 2), angle, 1)

        rotated_image = cv2.warpAffine(image, rotation_matrix, (width, height))
        rotated_mask = cv2.warpAffine(mask, rotation_matrix, (width, height))

        aug_images.append(rotated_image)
        aug_masks.append(rotated_mask)

    return aug_images, aug_masks

def grid_distort(image_array, mask_array, rows=10, cols=10):
    aug_images = []
    aug_masks = []
    for image, mask in zip(image_array, mask_array):
        distort_grid = np.indices(image.shape[:2], dtype=np.float32)
        distort_grid += np.random.normal(size=distort_grid.shape) * 10

        distort_grid[0] = np.clip(distort_grid[0], 0, image.shape[0] - 1)
        distort_grid[1] = np.clip(distort_grid[1], 0, image.shape[1] - 1)

        map_x = distort_grid[1]
        map_y = distort_grid[0]

        distorted_image = cv2.remap(image, map_x, map_y, cv2.INTER_LINEAR)
        distorted_mask = cv2.remap(mask, map_x, map_y, cv2.INTER_LINEAR)

        aug_images.append(distorted_image)
        aug_masks.append(distorted_mask)

    return aug_images, aug_masks

augmented_images, augmented_masks = flip_horizontal(training_array, mask_array)
augmented_images.extend(flip_vertical(training_array, mask_array)[0])
augmented_masks.extend(flip_vertical(training_array, mask_array)[1])
#augmented_images.extend(random_rotation(training_array, mask_array)[0])
#augmented_masks.extend(random_rotation(training_array, mask_array)[1])
augmented_images.extend(grid_distort(training_array, mask_array)[0])
augmented_masks.extend(grid_distort(training_array, mask_array)[1])


#preprocessed_augmented_images = np.array([preprocess_mask(img) for img in augmented_images])
#preprocessed_test_array = np.array([preprocess_mask(img) for img in test_array])
preprocessed_augmented_images = augmented_images
preprocessed_test_array = test_array

preprocessed_test_masks = [preprocess_mask(mask) for mask in test_mask_array]
preprocessed_augmented_masks = [preprocess_mask(mask) for mask in augmented_masks]

# %%
# horizontal/vertical flip, rotation, elastictransformation,  grid  distortion  and  optical  distortion.

# %%
index_to_check = 8
original_mask = test_mask_array[index_to_check]
preprocessed_mask = preprocessed_test_masks[index_to_check]

plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.imshow(original_mask)
plt.title('Original Mask')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(preprocessed_mask.squeeze(), cmap='gray')
plt.title('Preprocessed Mask')
plt.axis('off')

plt.show()

plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.hist(original_mask.ravel(), bins=256, color='blue', alpha=0.7)
plt.title('Original Mask Histogram')
plt.xlabel('Pixel Value')
plt.ylabel('Frequency')

plt.subplot(1, 2, 2)
plt.hist(preprocessed_mask.ravel(), bins=256, color='green', alpha=0.7)
plt.title('Preprocessed Mask Histogram')
plt.xlabel('Pixel Value')
plt.ylabel('Frequency')

plt.show()

print(f"Preprocessed mask shape: {preprocessed_mask.shape}")
print(f"Preprocessed mask data type: {preprocessed_mask.dtype}")
print(f"Preprocessed mask min value: {np.min(preprocessed_mask)}")
print(f"Preprocessed mask max value: {np.max(preprocessed_mask)}")
print(f"Preprocessed mask mean value: {np.mean(preprocessed_mask)}")
print(f"Preprocessed mask std deviation: {np.std(preprocessed_mask)}")
# Out:
# Preprocessed mask shape: (192, 192, 1)
# Preprocessed mask data type: float64
# Preprocessed mask min value: 0.0
# Preprocessed mask max value: 1.0
# Preprocessed mask mean value: 0.6839735243055556
# Preprocessed mask std deviation: 0.46492337256218164

# %%
print(len(preprocessed_augmented_images))
print(len(preprocessed_augmented_masks))
# Out:
# 1083
# 1083

# %%
#showing data aug results
plt.figure(figsize=(10, 10))
plt.subplots_adjust(wspace=0.2, hspace=0.2)

plt.subplot(3, 2, 1)
plt.imshow(preprocessed_augmented_images[1])
plt.title('Regular Training Image')
plt.axis('off')

plt.subplot(3, 2, 2)
plt.imshow(preprocessed_augmented_images[362])
plt.title('HFlip Training Image')
plt.axis('off')

#plt.subplot(3, 2, 3)
#plt.imshow(preprocessed_augmented_images[723])
#plt.title('Random Rotation Training Image')
#plt.axis('off')

plt.subplot(3, 2, 4)
plt.imshow(preprocessed_augmented_images[723])
plt.title('GridDistortion Training Image')
plt.axis('off')

plt.subplot(3, 2, 5)
plt.imshow(preprocessed_augmented_masks[362],cmap='gray')
plt.title('Augmented Mask HFlip')
plt.axis('off')

plt.show()

# %%
#constructing the UNET functions

def conv_block(inputs,filters):
  #two conv layers with batch normalization and relu, this makes features more apparent as the tiny weight get smaller and big ones grow
  conv = Conv2D(filters, kernel_size=(3, 3), strides=(1, 1), padding='same')(inputs)
  conv = BatchNormalization()(conv)
  conv = Activation('relu')(conv)
  conv = Conv2D(filters, kernel_size=(3, 3), strides=(1, 1), padding='same')(conv)
  conv = BatchNormalization()(conv)
  conv = Activation('relu')(conv)
  return conv

def attention_gate(input_tensor, skip_tensor, filters):
  #relu
  attn = Conv2D(filters, kernel_size=(1, 1), strides=(1, 1), padding='same')(input_tensor)
  attn = BatchNormalization()(attn)
  attn = Activation('relu')(attn)

  #sigmoid
  attn = Conv2D(filters, kernel_size=(1, 1), strides=(2, 2), padding='same')(attn)
  attn = BatchNormalization()(attn)
  attn = Activation('sigmoid')(attn)

  #resampler
  attn = UpSampling2D(size=(2, 2))(attn)
  attn = Conv2D(filters, kernel_size=(3, 3), strides=(1, 1), padding='same')(attn)

  #multiplication with the skip_tensor layer
  multiplied = tf.multiply(skip_tensor, attn)

  concatenated = Concatenate()([input_tensor, multiplied])
  return concatenated

def unet_build(input_shape):
  inputs = Input(input_shape)

  #downsampling
  conv1 = conv_block(inputs, 64)
  pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

  conv2 = conv_block(pool1, 128)
  pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

  conv3 = conv_block(pool2, 256)
  pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

  conv4 = conv_block(pool3, 512)
  pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

  #bridge
  conv5 = conv_block(pool4, 1024)

  #upsampling
  up6 = UpSampling2D(size=(2, 2))(conv5)
  up6 = attention_gate(up6, conv4, 512)
  conv6 = conv_block(up6, 512)

  up7 = UpSampling2D(size=(2, 2))(conv6)
  up7 = attention_gate(up7, conv3, 256)
  conv7 = conv_block(up7, 256)

  up8 = UpSampling2D(size=(2, 2))(conv7)
  up8 = attention_gate(up8, conv2, 128)
  conv8 = conv_block(up8, 128)

  up9 = UpSampling2D(size=(2, 2))(conv8)
  up9 = attention_gate(up9, conv1, 64)
  conv9 = conv_block(up9, 64)

  outputs = Conv2D(1, kernel_size=(1, 1), strides=(1, 1), activation='sigmoid')(conv9)

  model = Model(inputs=inputs, outputs=outputs)
  return model

# %%
#creation of the network
input_shape = (width, height, 3)
model = unet_build(input_shape)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 192, 192, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 192, 192, 64)         1792      ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 192, 192, 64)         256       ['conv2d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 192, 192, 64)         0         ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 192, 192, 64)         36928     ['activation[0][0]']
#
#  batch_normalization_1 (Bat  (None, 192, 192, 64)         256       ['conv2d_1[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 192, 192, 64)         0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  max_pooling2d (MaxPooling2  (None, 96, 96, 64)           0         ['activation_1[0][0]']
#  D)
#
#  conv2d_2 (Conv2D)           (None, 96, 96, 128)          73856     ['max_pooling2d[0][0]']
#
#  batch_normalization_2 (Bat  (None, 96, 96, 128)          512       ['conv2d_2[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 96, 96, 128)          0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  conv2d_3 (Conv2D)           (None, 96, 96, 128)          147584    ['activation_2[0][0]']
#
#  batch_normalization_3 (Bat  (None, 96, 96, 128)          512       ['conv2d_3[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 96, 96, 128)          0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  max_pooling2d_1 (MaxPoolin  (None, 48, 48, 128)          0         ['activation_3[0][0]']
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 48, 48, 256)          295168    ['max_pooling2d_1[0][0]']
#
#  batch_normalization_4 (Bat  (None, 48, 48, 256)          1024      ['conv2d_4[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 48, 48, 256)          0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  conv2d_5 (Conv2D)           (None, 48, 48, 256)          590080    ['activation_4[0][0]']
#
#  batch_normalization_5 (Bat  (None, 48, 48, 256)          1024      ['conv2d_5[0][0]']
#  chNormalization)
#
#  activation_5 (Activation)   (None, 48, 48, 256)          0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  max_pooling2d_2 (MaxPoolin  (None, 24, 24, 256)          0         ['activation_5[0][0]']
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 24, 24, 512)          1180160   ['max_pooling2d_2[0][0]']
#
#  batch_normalization_6 (Bat  (None, 24, 24, 512)          2048      ['conv2d_6[0][0]']
#  chNormalization)
#
#  activation_6 (Activation)   (None, 24, 24, 512)          0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  conv2d_7 (Conv2D)           (None, 24, 24, 512)          2359808   ['activation_6[0][0]']
#
#  batch_normalization_7 (Bat  (None, 24, 24, 512)          2048      ['conv2d_7[0][0]']
#  chNormalization)
#
#  activation_7 (Activation)   (None, 24, 24, 512)          0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  max_pooling2d_3 (MaxPoolin  (None, 12, 12, 512)          0         ['activation_7[0][0]']
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 12, 12, 1024)         4719616   ['max_pooling2d_3[0][0]']
#
#  batch_normalization_8 (Bat  (None, 12, 12, 1024)         4096      ['conv2d_8[0][0]']
#  chNormalization)
#
#  activation_8 (Activation)   (None, 12, 12, 1024)         0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  conv2d_9 (Conv2D)           (None, 12, 12, 1024)         9438208   ['activation_8[0][0]']
#
#  batch_normalization_9 (Bat  (None, 12, 12, 1024)         4096      ['conv2d_9[0][0]']
#  chNormalization)
#
#  activation_9 (Activation)   (None, 12, 12, 1024)         0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  up_sampling2d (UpSampling2  (None, 24, 24, 1024)         0         ['activation_9[0][0]']
#  D)
#
#  conv2d_10 (Conv2D)          (None, 24, 24, 512)          524800    ['up_sampling2d[0][0]']
#
#  batch_normalization_10 (Ba  (None, 24, 24, 512)          2048      ['conv2d_10[0][0]']
#  tchNormalization)
#
#  activation_10 (Activation)  (None, 24, 24, 512)          0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  conv2d_11 (Conv2D)          (None, 12, 12, 512)          262656    ['activation_10[0][0]']
#
#  batch_normalization_11 (Ba  (None, 12, 12, 512)          2048      ['conv2d_11[0][0]']
#  tchNormalization)
#
#  activation_11 (Activation)  (None, 12, 12, 512)          0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  up_sampling2d_1 (UpSamplin  (None, 24, 24, 512)          0         ['activation_11[0][0]']
#  g2D)
#
#  conv2d_12 (Conv2D)          (None, 24, 24, 512)          2359808   ['up_sampling2d_1[0][0]']
#
#  tf.math.multiply (TFOpLamb  (None, 24, 24, 512)          0         ['activation_7[0][0]',
#  da)                                                                 'conv2d_12[0][0]']
#
#  concatenate (Concatenate)   (None, 24, 24, 1536)         0         ['up_sampling2d[0][0]',
#                                                                      'tf.math.multiply[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 24, 24, 512)          7078400   ['concatenate[0][0]']
#
#  batch_normalization_12 (Ba  (None, 24, 24, 512)          2048      ['conv2d_13[0][0]']
#  tchNormalization)
#
#  activation_12 (Activation)  (None, 24, 24, 512)          0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  conv2d_14 (Conv2D)          (None, 24, 24, 512)          2359808   ['activation_12[0][0]']
#
#  batch_normalization_13 (Ba  (None, 24, 24, 512)          2048      ['conv2d_14[0][0]']
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 24, 24, 512)          0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  up_sampling2d_2 (UpSamplin  (None, 48, 48, 512)          0         ['activation_13[0][0]']
#  g2D)
#
#  conv2d_15 (Conv2D)          (None, 48, 48, 256)          131328    ['up_sampling2d_2[0][0]']
#
#  batch_normalization_14 (Ba  (None, 48, 48, 256)          1024      ['conv2d_15[0][0]']
#  tchNormalization)
#
#  activation_14 (Activation)  (None, 48, 48, 256)          0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  conv2d_16 (Conv2D)          (None, 24, 24, 256)          65792     ['activation_14[0][0]']
#
#  batch_normalization_15 (Ba  (None, 24, 24, 256)          1024      ['conv2d_16[0][0]']
#  tchNormalization)
#
#  activation_15 (Activation)  (None, 24, 24, 256)          0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  up_sampling2d_3 (UpSamplin  (None, 48, 48, 256)          0         ['activation_15[0][0]']
#  g2D)
#
#  conv2d_17 (Conv2D)          (None, 48, 48, 256)          590080    ['up_sampling2d_3[0][0]']
#
#  tf.math.multiply_1 (TFOpLa  (None, 48, 48, 256)          0         ['activation_5[0][0]',
#  mbda)                                                               'conv2d_17[0][0]']
#
#  concatenate_1 (Concatenate  (None, 48, 48, 768)          0         ['up_sampling2d_2[0][0]',
#  )                                                                   'tf.math.multiply_1[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 48, 48, 256)          1769728   ['concatenate_1[0][0]']
#
#  batch_normalization_16 (Ba  (None, 48, 48, 256)          1024      ['conv2d_18[0][0]']
#  tchNormalization)
#
#  activation_16 (Activation)  (None, 48, 48, 256)          0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  conv2d_19 (Conv2D)          (None, 48, 48, 256)          590080    ['activation_16[0][0]']
#
#  batch_normalization_17 (Ba  (None, 48, 48, 256)          1024      ['conv2d_19[0][0]']
#  tchNormalization)
#
#  activation_17 (Activation)  (None, 48, 48, 256)          0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  up_sampling2d_4 (UpSamplin  (None, 96, 96, 256)          0         ['activation_17[0][0]']
#  g2D)
#
#  conv2d_20 (Conv2D)          (None, 96, 96, 128)          32896     ['up_sampling2d_4[0][0]']
#
#  batch_normalization_18 (Ba  (None, 96, 96, 128)          512       ['conv2d_20[0][0]']
#  tchNormalization)
#
#  activation_18 (Activation)  (None, 96, 96, 128)          0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  conv2d_21 (Conv2D)          (None, 48, 48, 128)          16512     ['activation_18[0][0]']
#
#  batch_normalization_19 (Ba  (None, 48, 48, 128)          512       ['conv2d_21[0][0]']
#  tchNormalization)
#
#  activation_19 (Activation)  (None, 48, 48, 128)          0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  up_sampling2d_5 (UpSamplin  (None, 96, 96, 128)          0         ['activation_19[0][0]']
#  g2D)
#
#  conv2d_22 (Conv2D)          (None, 96, 96, 128)          147584    ['up_sampling2d_5[0][0]']
#
#  tf.math.multiply_2 (TFOpLa  (None, 96, 96, 128)          0         ['activation_3[0][0]',
#  mbda)                                                               'conv2d_22[0][0]']
#
#  concatenate_2 (Concatenate  (None, 96, 96, 384)          0         ['up_sampling2d_4[0][0]',
#  )                                                                   'tf.math.multiply_2[0][0]']
#
#  conv2d_23 (Conv2D)          (None, 96, 96, 128)          442496    ['concatenate_2[0][0]']
#
#  batch_normalization_20 (Ba  (None, 96, 96, 128)          512       ['conv2d_23[0][0]']
#  tchNormalization)
#
#  activation_20 (Activation)  (None, 96, 96, 128)          0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  conv2d_24 (Conv2D)          (None, 96, 96, 128)          147584    ['activation_20[0][0]']
#
#  batch_normalization_21 (Ba  (None, 96, 96, 128)          512       ['conv2d_24[0][0]']
#  tchNormalization)
#
#  activation_21 (Activation)  (None, 96, 96, 128)          0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  up_sampling2d_6 (UpSamplin  (None, 192, 192, 128)        0         ['activation_21[0][0]']
#  g2D)
#
#  conv2d_25 (Conv2D)          (None, 192, 192, 64)         8256      ['up_sampling2d_6[0][0]']
#
#  batch_normalization_22 (Ba  (None, 192, 192, 64)         256       ['conv2d_25[0][0]']
#  tchNormalization)
#
#  activation_22 (Activation)  (None, 192, 192, 64)         0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  conv2d_26 (Conv2D)          (None, 96, 96, 64)           4160      ['activation_22[0][0]']
#
#  batch_normalization_23 (Ba  (None, 96, 96, 64)           256       ['conv2d_26[0][0]']
#  tchNormalization)
#
#  activation_23 (Activation)  (None, 96, 96, 64)           0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  up_sampling2d_7 (UpSamplin  (None, 192, 192, 64)         0         ['activation_23[0][0]']
#  g2D)
#
#  conv2d_27 (Conv2D)          (None, 192, 192, 64)         36928     ['up_sampling2d_7[0][0]']
#
#  tf.math.multiply_3 (TFOpLa  (None, 192, 192, 64)         0         ['activation_1[0][0]',
#  mbda)                                                               'conv2d_27[0][0]']
#
#  concatenate_3 (Concatenate  (None, 192, 192, 192)        0         ['up_sampling2d_6[0][0]',
#  )                                                                   'tf.math.multiply_3[0][0]']
#
#  conv2d_28 (Conv2D)          (None, 192, 192, 64)         110656    ['concatenate_3[0][0]']
#
#  batch_normalization_24 (Ba  (None, 192, 192, 64)         256       ['conv2d_28[0][0]']
#  tchNormalization)
#
#  activation_24 (Activation)  (None, 192, 192, 64)         0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  conv2d_29 (Conv2D)          (None, 192, 192, 64)         36928     ['activation_24[0][0]']
#
#  batch_normalization_25 (Ba  (None, 192, 192, 64)         256       ['conv2d_29[0][0]']
#  tchNormalization)
#
#  activation_25 (Activation)  (None, 192, 192, 64)         0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  conv2d_30 (Conv2D)          (None, 192, 192, 1)          65        ['activation_25[0][0]']
#
# ==================================================================================================
# Total params: 35590977 (135.77 MB)
# Trainable params: 35575361 (135.71 MB)
# Non-trainable params: 15616 (61.00 KB)
# __________________________________________________________________________________________________

# %%
preprocessed_augmented_images = np.array(preprocessed_augmented_images)
preprocessed_augmented_masks = np.array(preprocessed_augmented_masks)
preprocessed_test_array = np.array(preprocessed_test_array)
preprocessed_test_masks= np.array(preprocessed_test_masks)

# %%
print("Shape of augmented_images:", preprocessed_augmented_images.shape)
print("Shape of augmented_masks:", preprocessed_augmented_masks.shape)
print("Shape of test_array:", preprocessed_test_array.shape)
print("Shape of test_mask_array:", preprocessed_test_masks.shape)
# Out:
# Shape of augmented_images: (1083, 192, 192, 3)
# Shape of augmented_masks: (1083, 192, 192, 1)
# Shape of test_array: (61, 192, 192, 3)
# Shape of test_mask_array: (61, 192, 192, 1)

# %%
#augmented_images_with_channel = np.concatenate([augmented_images, np.ones_like(augmented_images[..., :1])], axis=-1)
#test_array_with_channel = np.concatenate([test_array, np.ones_like(test_array[..., :1])], axis=-1)

#print("Shape of augmented_images after adding channel:", augmented_images_with_channel.shape)
#print("Shape of test_array after adding channel:", test_array_with_channel.shape)

# %%
plt.subplot(3, 2, 1)
plt.imshow(preprocessed_test_array[1])
plt.axis('off')

plt.subplot(3, 2, 2)
plt.imshow(preprocessed_test_masks[1])
plt.axis('off')

plt.show()

# %%
#training
model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])


#test_images = np.squeeze(test_images)
#test_masks = np.squeeze(test_masks)
#print("Updated Test images shape:", test_images.shape)
#print("Updated Test masks shape:", test_masks.shape)



history = model.fit(preprocessed_augmented_images,
                    preprocessed_augmented_masks,
                    validation_data=(preprocessed_test_array, preprocessed_test_masks),
                    epochs=50,
                    batch_size=8)
# Out:
# Epoch 1/50
# 136/136 [==============================] - 117s 560ms/step - loss: 0.5307 - accuracy: 0.7301 - val_loss: 1.8350 - val_accuracy: 0.4431
# Epoch 2/50
# 136/136 [==============================] - 57s 420ms/step - loss: 0.4645 - accuracy: 0.7830 - val_loss: 1.1617 - val_accuracy: 0.4486
# Epoch 3/50
# 136/136 [==============================] - 57s 421ms/step - loss: 0.4431 - accuracy: 0.7952 - val_loss: 0.9830 - val_accuracy: 0.4996
# Epoch 4/50
# 136/136 [==============================] - 57s 419ms/step - loss: 0.4246 - accuracy: 0.8064 - val_loss: 0.6268 - val_accuracy: 0.7500
# Epoch 5/50
# 136/136 [==============================] - 57s 421ms/step - loss: 0.4103 - accuracy: 0.8182 - val_loss: 0.3679 - val_accuracy: 0.8331
# Epoch 6/50
# 136/136 [==============================] - 57s 419ms/step - loss: 0.3979 - accuracy: 0.8235 - val_loss: 0.6143 - val_accuracy: 0.7418
# Epoch 7/50
# 136/136 [==============================] - 57s 421ms/step - loss: 0.3945 - accuracy: 0.8259 - val_loss: 0.9674 - val_accuracy: 0.6913
# Epoch 8/50
# 136/136 [==============================] - 57s 419ms/step - loss: 0.3924 - accuracy: 0.8258 - val_loss: 0.4676 - val_accuracy: 0.7659
# Epoch 9/50
# 136/136 [==============================] - 57s 421ms/step - loss: 0.3918 - accuracy: 0.8273 - val_loss: 1.9655 - val_accuracy: 0.4669
# Epoch 10/50
# 136/136 [==============================] - 57s 419ms/step - loss: 0.3772 - accuracy: 0.8366 - val_loss: 0.8783 - val_accuracy: 0.6008
# Epoch 11/50
# 136/136 [==============================] - 57s 420ms/step - loss: 0.3854 - accuracy: 0.8287 - val_loss: 0.3756 - val_accuracy: 0.8481
# Epoch 12/50
# 136/136 [==============================] - 57s 421ms/step - loss: 0.3626 - accuracy: 0.8442 - val_loss: 0.5615 - val_accuracy: 0.6937
# Epoch 13/50
# 136/136 [==============================] - 57s 421ms/step - loss: 0.3547 - accuracy: 0.8459 - val_loss: 0.6302 - val_accuracy: 0.7338
# Epoch 14/50
# 136/136 [==============================] - 57s 421ms/step - loss: 0.3494 - accuracy: 0.8501 - val_loss: 0.7403 - val_accuracy: 0.6888
# Epoch 15/50
# 136/136 [==============================] - 57s 419ms/step - loss: 0.3531 - accuracy: 0.8489 - val_loss: 0.4264 - val_accuracy: 0.8227
# Epoch 16/50
# 136/136 [==============================] - 57s 419ms/step - loss: 0.3601 - accuracy: 0.8439 - val_loss: 0.4444 - val_accuracy: 0.8068
# Epoch 17/50
# 136/136 [==============================] - 57s 419ms/step - loss: 0.3433 - accuracy: 0.8538 - val_loss: 0.6145 - val_accuracy: 0.6785
# Epoch 18/50
# 136/136 [==============================] - 57s 419ms/step - loss: 0.3300 - accuracy: 0.8583 - val_loss: 0.5126 - val_accuracy: 0.7324
# Epoch 19/50
# 136/136 [==============================] - 57s 421ms/step - loss: 0.3271 - accuracy: 0.8601 - val_loss: 0.4484 - val_accuracy: 0.8076
# Epoch 20/50
# 136/136 [==============================] - 57s 419ms/step - loss: 0.3224 - accuracy: 0.8626 - val_loss: 0.4920 - val_accuracy: 0.8136
# Epoch 21/50
# 136/136 [==============================] - 57s 420ms/step - loss: 0.3272 - accuracy: 0.8581 - val_loss: 1.1812 - val_accuracy: 0.6370
# Epoch 22/50
# 136/136 [==============================] - 57s 419ms/step - loss: 0.3212 - accuracy: 0.8602 - val_loss: 0.3746 - val_accuracy: 0.8238
# Epoch 23/50
# 136/136 [==============================] - 57s 419ms/step - loss: 0.3166 - accuracy: 0.8645 - val_loss: 0.5177 - val_accuracy: 0.7909
# Epoch 24/50
# 136/136 [==============================] - 57s 421ms/step - loss: 0.3054 - accuracy: 0.8707 - val_loss: 0.2887 - val_accuracy: 0.8863
# Epoch 25/50
# 136/136 [==============================] - 57s 419ms/step - loss: 0.3180 - accuracy: 0.8653 - val_loss: 1.8399 - val_accuracy: 0.6360
# Epoch 26/50
# 136/136 [==============================] - 57s 419ms/step - loss: 0.3226 - accuracy: 0.8627 - val_loss: 1.0676 - val_accuracy: 0.6084
# Epoch 27/50
# 136/136 [==============================] - 57s 419ms/step - loss: 0.2919 - accuracy: 0.8763 - val_loss: 1.0353 - val_accuracy: 0.7027
# Epoch 28/50
# 136/136 [==============================] - 57s 421ms/step - loss: 0.2944 - accuracy: 0.8751 - val_loss: 0.8518 - val_accuracy: 0.6420
# Epoch 29/50
# 136/136 [==============================] - 57s 421ms/step - loss: 0.2916 - accuracy: 0.8768 - val_loss: 0.4828 - val_accuracy: 0.7986
# Epoch 30/50
# 136/136 [==============================] - 57s 420ms/step - loss: 0.2883 - accuracy: 0.8768 - val_loss: 0.9625 - val_accuracy: 0.6080
# Epoch 31/50
# 136/136 [==============================] - 57s 419ms/step - loss: 0.2872 - accuracy: 0.8779 - val_loss: 0.5764 - val_accuracy: 0.7602
# Epoch 32/50
# 136/136 [==============================] - 57s 421ms/step - loss: 0.2853 - accuracy: 0.8794 - val_loss: 0.3803 - val_accuracy: 0.8354
# Epoch 33/50
# 136/136 [==============================] - 57s 421ms/step - loss: 0.2902 - accuracy: 0.8761 - val_loss: 0.6840 - val_accuracy: 0.7298
# Epoch 34/50
# 136/136 [==============================] - 57s 421ms/step - loss: 0.2775 - accuracy: 0.8829 - val_loss: 2.5623 - val_accuracy: 0.5741
# Epoch 35/50
# 136/136 [==============================] - 57s 421ms/step - loss: 0.2860 - accuracy: 0.8799 - val_loss: 0.9201 - val_accuracy: 0.6381
# Epoch 36/50
# 136/136 [==============================] - 57s 421ms/step - loss: 0.2658 - accuracy: 0.8886 - val_loss: 0.3904 - val_accuracy: 0.8369
# Epoch 37/50
# 136/136 [==============================] - 57s 421ms/step - loss: 0.2797 - accuracy: 0.8818 - val_loss: 0.4577 - val_accuracy: 0.7661
# Epoch 38/50
# 136/136 [==============================] - 57s 420ms/step - loss: 0.2676 - accuracy: 0.8864 - val_loss: 0.9819 - val_accuracy: 0.6558
# Epoch 39/50
# 136/136 [==============================] - 57s 422ms/step - loss: 0.2671 - accuracy: 0.8873 - val_loss: 0.5703 - val_accuracy: 0.7244
# Epoch 40/50
# 136/136 [==============================] - 57s 420ms/step - loss: 0.2716 - accuracy: 0.8846 - val_loss: 0.2880 - val_accuracy: 0.8706
# Epoch 41/50
# 136/136 [==============================] - 57s 420ms/step - loss: 0.2829 - accuracy: 0.8816 - val_loss: 0.5070 - val_accuracy: 0.7989
# Epoch 42/50
# 136/136 [==============================] - 57s 420ms/step - loss: 0.2674 - accuracy: 0.8870 - val_loss: 0.3538 - val_accuracy: 0.8289
# Epoch 43/50
# 136/136 [==============================] - 57s 420ms/step - loss: 0.2586 - accuracy: 0.8907 - val_loss: 0.4501 - val_accuracy: 0.8057
# Epoch 44/50
# 136/136 [==============================] - 57s 422ms/step - loss: 0.2604 - accuracy: 0.8902 - val_loss: 0.4679 - val_accuracy: 0.8076
# Epoch 45/50
# 136/136 [==============================] - 57s 421ms/step - loss: 0.2614 - accuracy: 0.8895 - val_loss: 0.3607 - val_accuracy: 0.8408
# Epoch 46/50
# 136/136 [==============================] - 57s 422ms/step - loss: 0.2550 - accuracy: 0.8937 - val_loss: 1.6608 - val_accuracy: 0.6595
# Epoch 47/50
# 136/136 [==============================] - 57s 422ms/step - loss: 0.2505 - accuracy: 0.8950 - val_loss: 0.4456 - val_accuracy: 0.8144
# Epoch 48/50
# 136/136 [==============================] - 57s 420ms/step - loss: 0.2561 - accuracy: 0.8912 - val_loss: 0.3927 - val_accuracy: 0.8197
# Epoch 49/50
# 136/136 [==============================] - 57s 422ms/step - loss: 0.2609 - accuracy: 0.8882 - val_loss: 0.7267 - val_accuracy: 0.7530
# Epoch 50/50
# 136/136 [==============================] - 57s 420ms/step - loss: 0.2434 - accuracy: 0.8972 - val_loss: 0.3900 - val_accuracy: 0.8257

# %%
#evaluate the model
loss, accuracy = model.evaluate(preprocessed_test_array, preprocessed_test_masks)
print("Test Loss:", loss)
print("Test Accuracy:", accuracy)
# Out:
# 2/2 [==============================] - 34s 17s/step - loss: 0.3900 - accuracy: 0.8257
# Test Loss: 0.3899889588356018
# Test Accuracy: 0.8257414102554321

# %%
#testing

image_index = 6

test_image = preprocessed_test_array[image_index]
test_mask = preprocessed_test_masks[image_index]

test_image = np.expand_dims(test_image, axis=0)

predicted_mask = model.predict(test_image)

threshold_value = 0.2
thresholded_mask = (predicted_mask > threshold_value).astype(np.uint8)

plt.figure(figsize=(12, 6))

plt.subplot(1, 3, 1)
plt.imshow(test_image.squeeze(), cmap='gray')
plt.axis('off')
plt.title('Original Image')

plt.subplot(1, 3, 2)
plt.imshow(test_mask.squeeze(), cmap='gray')
plt.axis('off')
plt.title('Ground Truth Mask')

plt.subplot(1, 3, 3)
plt.imshow(thresholded_mask.squeeze(), cmap='gray')  # Use thresholded mask here
plt.axis('off')
plt.title('Thresholded Predicted Mask')

plt.show()
# Out:
# 1/1 [==============================] - 0s 38ms/step

# %%
fig, axs = plt.subplots(1, 2, figsize=(15, 5))

axs[0].imshow(test_image.squeeze())
axs[0].imshow(thresholded_mask.squeeze(), alpha=0.5)
axs[0].axis('off')
axs[0].set_title('Overlay with the predicted mask')

axs[1].imshow(test_image.squeeze())
axs[1].imshow(test_mask.squeeze(), alpha=0.5)
axs[1].axis('off')
axs[1].set_title('Overlay with the original mask')

plt.tight_layout()

plt.show()

# %%
#analytics

plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

plt.figure(figsize=(12, 6))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
